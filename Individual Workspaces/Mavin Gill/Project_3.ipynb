# %%
#API Call of Ocean Warming Data
import requests

# New API URL
url = "https://global-warming.org/api/ocean-warming-api"

try:
    # Make the API request
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()  # Parse the JSON response

        # Extract the result dictionary from the data
        result = data['result']

        # Convert string values to floats
        ocean_warming_data = {year: float(value) for year, value in result.items()}

        print("Ocean warming data:")
        for year, value in ocean_warming_data.items():
            print(f"Year: {year}, Ocean Warming: {value}°C")
    else:
        print(f"API request failed with status code: {response.status_code}")
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
# Out:
# Ocean warming data:
# Year: 1880, Ocean Warming: -0.02°C
# Year: 1881, Ocean Warming: 0.04°C
# Year: 1882, Ocean Warming: 0.03°C
# Year: 1883, Ocean Warming: -0.04°C
# Year: 1884, Ocean Warming: -0.12°C
# Year: 1885, Ocean Warming: -0.17°C
# Year: 1886, Ocean Warming: -0.16°C
# Year: 1887, Ocean Warming: -0.2°C
# Year: 1888, Ocean Warming: -0.01°C
# Year: 1889, Ocean Warming: 0.0°C
# Year: 1890, Ocean Warming: -0.24°C
# Year: 1891, Ocean Warming: -0.09°C
# Year: 1892, Ocean Warming: -0.13°C
# Year: 1893, Ocean Warming: -0.19°C
# Year: 1894, Ocean Warming: -0.21°C
# Year: 1895, Ocean Warming: -0.1°C
# Year: 1896, Ocean Warming: 0.03°C
# Year: 1897, Ocean Warming: -0.01°C
# Year: 1898, Ocean Warming: -0.17°C
# Year: 1899, Ocean Warming: -0.1°C
# Year: 1900, Ocean Warming: -0.02°C
# Year: 1901, Ocean Warming: -0.12°C
# Year: 1902, Ocean Warming: -0.19°C
# Year: 1903, Ocean Warming: -0.33°C
# Year: 1904, Ocean Warming: -0.43°C
# Year: 1905, Ocean Warming: -0.22°C
# Year: 1906, Ocean Warming: -0.19°C
# Year: 1907, Ocean Warming: -0.27°C
# Year: 1908, Ocean Warming: -0.4°C
# Year: 1909, Ocean Warming: -0.44°C
# Year: 1910, Ocean Warming: -0.41°C
# Year: 1911, Ocean Warming: -0.4°C
# Year: 1912, Ocean Warming: -0.25°C
# Year: 1913, Ocean Warming: -0.3°C
# Year: 1914, Ocean Warming: -0.15°C
# Year: 1915, Ocean Warming: -0.08°C
# Year: 1916, Ocean Warming: -0.26°C
# Year: 1917, Ocean Warming: -0.32°C
# Year: 1918, Ocean Warming: -0.18°C
# Year: 1919, Ocean Warming: -0.2°C
# Year: 1920, Ocean Warming: -0.21°C
# Year: 1921, Ocean Warming: -0.19°C
# Year: 1922, Ocean Warming: -0.24°C
# Year: 1923, Ocean Warming: -0.24°C
# Year: 1924, Ocean Warming: -0.24°C
# Year: 1925, Ocean Warming: -0.21°C
# Year: 1926, Ocean Warming: -0.11°C
# Year: 1927, Ocean Warming: -0.17°C
# Year: 1928, Ocean Warming: -0.21°C
# Year: 1929, Ocean Warming: -0.27°C
# Year: 1930, Ocean Warming: -0.14°C
# Year: 1931, Ocean Warming: -0.1°C
# Year: 1932, Ocean Warming: -0.18°C
# Year: 1933, Ocean Warming: -0.23°C
# Year: 1934, Ocean Warming: -0.16°C
# Year: 1935, Ocean Warming: -0.17°C
# Year: 1936, Ocean Warming: -0.13°C
# Year: 1937, Ocean Warming: -0.03°C
# Year: 1938, Ocean Warming: -0.11°C
# Year: 1939, Ocean Warming: -0.04°C
# Year: 1940, Ocean Warming: 0.16°C
# Year: 1941, Ocean Warming: 0.28°C
# Year: 1942, Ocean Warming: 0.1°C
# Year: 1943, Ocean Warming: 0.08°C
# Year: 1944, Ocean Warming: 0.23°C
# Year: 1945, Ocean Warming: 0.21°C
# Year: 1946, Ocean Warming: -0.05°C
# Year: 1947, Ocean Warming: -0.06°C
# Year: 1948, Ocean Warming: -0.1°C
# Year: 1949, Ocean Warming: -0.07°C
# Year: 1950, Ocean Warming: -0.09°C
# Year: 1951, Ocean Warming: 0.0°C
# Year: 1952, Ocean Warming: 0.07°C
# Year: 1953, Ocean Warming: 0.06°C
# Year: 1954, Ocean Warming: -0.11°C
# Year: 1955, Ocean Warming: -0.12°C
# Year: 1956, Ocean Warming: -0.1°C
# Year: 1957, Ocean Warming: 0.1°C
# Year: 1958, Ocean Warming: 0.12°C
# Year: 1959, Ocean Warming: 0.06°C
# Year: 1960, Ocean Warming: 0.06°C
# Year: 1961, Ocean Warming: 0.08°C
# Year: 1962, Ocean Warming: 0.06°C
# Year: 1963, Ocean Warming: 0.08°C
# Year: 1964, Ocean Warming: -0.08°C
# Year: 1965, Ocean Warming: -0.04°C
# Year: 1966, Ocean Warming: 0.02°C
# Year: 1967, Ocean Warming: 0.0°C
# Year: 1968, Ocean Warming: 0.02°C
# Year: 1969, Ocean Warming: 0.19°C
# Year: 1970, Ocean Warming: 0.07°C
# Year: 1971, Ocean Warming: -0.06°C
# Year: 1972, Ocean Warming: 0.12°C
# Year: 1973, Ocean Warming: 0.15°C
# Year: 1974, Ocean Warming: -0.01°C
# Year: 1975, Ocean Warming: -0.02°C
# Year: 1976, Ocean Warming: 0.02°C
# Year: 1977, Ocean Warming: 0.2°C
# Year: 1978, Ocean Warming: 0.14°C
# Year: 1979, Ocean Warming: 0.27°C
# Year: 1980, Ocean Warming: 0.28°C
# Year: 1981, Ocean Warming: 0.25°C
# Year: 1982, Ocean Warming: 0.24°C
# Year: 1983, Ocean Warming: 0.32°C
# Year: 1984, Ocean Warming: 0.21°C
# Year: 1985, Ocean Warming: 0.18°C
# Year: 1986, Ocean Warming: 0.23°C
# Year: 1987, Ocean Warming: 0.38°C
# Year: 1988, Ocean Warming: 0.33°C
# Year: 1989, Ocean Warming: 0.28°C
# Year: 1990, Ocean Warming: 0.37°C
# Year: 1991, Ocean Warming: 0.34°C
# Year: 1992, Ocean Warming: 0.25°C
# Year: 1993, Ocean Warming: 0.26°C
# Year: 1994, Ocean Warming: 0.3°C
# Year: 1995, Ocean Warming: 0.34°C
# Year: 1996, Ocean Warming: 0.31°C
# Year: 1997, Ocean Warming: 0.47°C
# Year: 1998, Ocean Warming: 0.52°C
# Year: 1999, Ocean Warming: 0.31°C
# Year: 2000, Ocean Warming: 0.33°C
# Year: 2001, Ocean Warming: 0.45°C
# Year: 2002, Ocean Warming: 0.48°C
# Year: 2003, Ocean Warming: 0.5°C
# Year: 2004, Ocean Warming: 0.49°C
# Year: 2005, Ocean Warming: 0.49°C
# Year: 2006, Ocean Warming: 0.49°C
# Year: 2007, Ocean Warming: 0.4°C
# Year: 2008, Ocean Warming: 0.39°C
# Year: 2009, Ocean Warming: 0.52°C
# Year: 2010, Ocean Warming: 0.53°C
# Year: 2011, Ocean Warming: 0.41°C
# Year: 2012, Ocean Warming: 0.48°C
# Year: 2013, Ocean Warming: 0.52°C
# Year: 2014, Ocean Warming: 0.61°C
# Year: 2015, Ocean Warming: 0.72°C
# Year: 2016, Ocean Warming: 0.75°C
# Year: 2017, Ocean Warming: 0.69°C
# Year: 2018, Ocean Warming: 0.66°C
# Year: 2019, Ocean Warming: 0.74°C
# Year: 2020, Ocean Warming: 0.72°C
# Year: 2021, Ocean Warming: 0.63°C
# Year: 2022, Ocean Warming: 0.67°C

# %%
# API URL
url = "https://global-warming.org/api/ocean-warming-api"

try:
    # Make the API request
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()  # Parse the JSON response

        # Extract years from the 'result' dictionary
        years = [year for year in data['result'].keys()]

        # Count the number of entries (years)
        num_entries = len(years)

        print(f"Number of entries (years): {num_entries}")
    else:
        print(f"API request failed with status code: {response.status_code}")
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
# Out:
# Number of entries (years): 143

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Specify the path to your JSON file
json_file_path = "data.json"

try:
    # Open and read the JSON file
    with open(json_file_path, "r") as json_file:
        data = json.load(json_file)  # Load the JSON data

        # Extract temperature anomalies data from the 'data' dictionary
        anomalies = data['data']

        # Extract years and anomalies as separate lists
        years = [int(year) for year in anomalies.keys()]
        anomaly_values = [float(value) for value in anomalies.values()]

        # Create a line chart using Matplotlib
        plt.figure(figsize=(10, 6))
        plt.plot(years, anomaly_values, marker='o')
        plt.xlabel('Year')
        plt.ylabel('Temperature Anomaly (°C)')
        plt.title('Global Land and Ocean Temperature Anomalies')

        # Format x-axis labels as years
        plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: str(int(x))[:4]))

        plt.grid(True)
        plt.show()

except FileNotFoundError:
    print(f"File '{json_file_path}' not found.")
except json.JSONDecodeError:
    print(f"Error decoding JSON from '{json_file_path}'.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
import csv

# Specify the path to your CSV file
csv_file_path = "Global_Land_OceanTemp_Anom.csv"

try:
    # Open and read the CSV file
    with open(csv_file_path, "r") as csv_file:
        csv_reader = csv.reader(csv_file)  # Create a CSV reader object
        
        # Skip the first 5 rows
        for _ in range(5):
            next(csv_reader)

        # Loop through each row starting from the 6th row
        for row in csv_reader:
            # Process the row as needed
            print(row)
except FileNotFoundError:
    print(f"File '{csv_file_path}' not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# ['185001', '-0.39']
# ['185002', '-0.15']
# ['185003', '-0.26']
# ['185004', '-0.22']
# ['185005', '-0.21']
# ['185006', '-0.13']
# ['185007', '-0.11']
# ['185008', '-0.13']
# ['185009', '-0.21']
# ['185010', '-0.13']
# ['185011', '-0.16']
# ['185012', '-0.07']
# ['185101', '-0.14']
# ['185102', '-0.09']
# ['185103', '-0.26']
# ['185104', '-0.18']
# ['185105', '-0.10']
# ['185106', '-0.17']
# ['185107', '-0.06']
# ['185108', '-0.03']
# ['185109', '-0.01']
# ['185110', '-0.05']
# ['185111', '-0.06']
# ['185112', '-0.04']
# ['185201', '-0.16']
# ['185202', '-0.10']
# ['185203', '-0.27']
# ['185204', '-0.38']
# ['185205', '-0.01']
# ['185206', '-0.09']
# ['185207', '-0.06']
# ['185208', '0.05']
# ['185209', '-0.03']
# ['185210', '-0.08']
# ['185211', '-0.06']
# ['185212', '-0.10']
# ['185301', '-0.02']
# ['185302', '-0.16']
# ['185303', '-0.16']
# ['185304', '-0.19']
# ['185305', '-0.14']
# ['185306', '-0.08']
# ['185307', '-0.03']
# ['185308', '-0.04']
# ['185309', '-0.13']
# ['185310', '-0.17']
# ['185311', '-0.15']
# ['185312', '-0.23']
# ['185401', '-0.25']
# ['185402', '-0.19']
# ['185403', '-0.06']
# ['185404', '-0.23']
# ['185405', '-0.09']
# ['185406', '-0.08']
# ['185407', '-0.13']
# ['185408', '-0.15']
# ['185409', '-0.08']
# ['185410', '-0.04']
# ['185411', '-0.15']
# ['185412', '0.01']
# ['185501', '-0.01']
# ['185502', '-0.12']
# ['185503', '-0.16']
# ['185504', '-0.10']
# ['185505', '-0.14']
# ['185506', '-0.21']
# ['185507', '-0.14']
# ['185508', '-0.16']
# ['185509', '-0.20']
# ['185510', '-0.05']
# ['185511', '0.02']
# ['185512', '-0.21']
# ['185601', '-0.10']
# ['185602', '-0.08']
# ['185603', '-0.29']
# ['185604', '-0.18']
# ['185605', '-0.14']
# ['185606', '-0.16']
# ['185607', '-0.35']
# ['185608', '-0.32']
# ['185609', '-0.19']
# ['185610', '-0.46']
# ['185611', '-0.48']
# ['185612', '-0.38']
# ['185701', '-0.30']
# ['185702', '-0.35']
# ['185703', '-0.33']
# ['185704', '-0.38']
# ['185705', '-0.36']
# ['185706', '-0.31']
# ['185707', '-0.25']
# ['185708', '-0.19']
# ['185709', '-0.21']
# ['185710', '-0.27']
# ['185711', '-0.30']
# ['185712', '-0.17']
# ['185801', '-0.18']
# ['185802', '-0.32']
# ['185803', '-0.20']
# ['185804', '-0.21']
# ['185805', '-0.23']
# ['185806', '-0.21']
# ['185807', '-0.21']
# ['185808', '-0.24']
# ['185809', '-0.22']
# ['185810', '-0.23']
# ['185811', '-0.20']
# ['185812', '-0.21']
# ['185901', '-0.12']
# ['185902', '0.00']
# ['185903', '-0.05']
# ['185904', '-0.09']
# ['185905', '-0.10']
# ['185906', '-0.12']
# ['185907', '-0.12']
# ['185908', '-0.15']
# ['185909', '-0.14']
# ['185910', '-0.14']
# ['185911', '-0.08']
# ['185912', '-0.05']
# ['186001', '-0.14']
# ['186002', '-0.12']
# ['186003', '-0.20']
# ['186004', '-0.19']
# ['186005', '-0.16']
# ['186006', '-0.20']
# ['186007', '-0.27']
# ['186008', '-0.26']
# ['186009', '-0.23']
# ['186010', '-0.24']
# ['186011', '-0.34']
# ['186012', '-0.49']
# ['186101', '-0.48']
# ['186102', '-0.32']
# ['186103', '-0.28']
# ['186104', '-0.30']
# ['186105', '-0.25']
# ['186106', '-0.29']
# ['186107', '-0.19']
# ['186108', '-0.11']
# ['186109', '-0.11']
# ['186110', '-0.25']
# ['186111', '-0.26']
# ['186112', '-0.25']
# ['186201', '-0.42']
# ['186202', '-0.36']
# ['186203', '-0.28']
# ['186204', '-0.30']
# ['186205', '-0.35']
# ['186206', '-0.33']
# ['186207', '-0.31']
# ['186208', '-0.32']
# ['186209', '-0.24']
# ['186210', '-0.29']
# ['186211', '-0.20']
# ['186212', '-0.30']
# ['186301', '-0.06']
# ['186302', '-0.09']
# ['186303', '-0.13']
# ['186304', '-0.16']
# ['186305', '-0.13']
# ['186306', '-0.25']
# ['186307', '-0.24']
# ['186308', '-0.15']
# ['186309', '-0.21']
# ['186310', '-0.23']
# ['186311', '-0.19']
# ['186312', '-0.09']
# ['186401', '-0.35']
# ['186402', '-0.21']
# ['186403', '-0.19']
# ['186404', '-0.21']
# ['186405', '-0.14']
# ['186406', '-0.10']
# ['186407', '-0.16']
# ['186408', '-0.18']
# ['186409', '-0.25']
# ['186410', '-0.28']
# ['186411', '-0.20']
# ['186412', '-0.12']
# ['186501', '-0.05']
# ['186502', '-0.25']
# ['186503', '-0.18']
# ['186504', '-0.16']
# ['186505', '-0.18']
# ['186506', '-0.14']
# ['186507', '-0.08']
# ['186508', '-0.09']
# ['186509', '-0.10']
# ['186510', '-0.16']
# ['186511', '-0.11']
# ['186512', '-0.12']
# ['186601', '0.08']
# ['186602', '-0.06']
# ['186603', '-0.08']
# ['186604', '-0.17']
# ['186605', '-0.19']
# ['186606', '-0.11']
# ['186607', '-0.07']
# ['186608', '-0.18']
# ['186609', '-0.20']
# ['186610', '-0.19']
# ['186611', '-0.06']
# ['186612', '-0.10']
# ['186701', '-0.22']
# ['186702', '-0.09']
# ['186703', '-0.21']
# ['186704', '-0.19']
# ['186705', '-0.27']
# ['186706', '-0.19']
# ['186707', '-0.23']
# ['186708', '-0.13']
# ['186709', '-0.04']
# ['186710', '-0.13']
# ['186711', '-0.16']
# ['186712', '-0.34']
# ['186801', '-0.43']
# ['186802', '-0.24']
# ['186803', '-0.10']
# ['186804', '-0.10']
# ['186805', '-0.01']
# ['186806', '-0.04']
# ['186807', '-0.12']
# ['186808', '-0.11']
# ['186809', '-0.19']
# ['186810', '-0.14']
# ['186811', '-0.15']
# ['186812', '-0.10']
# ['186901', '-0.15']
# ['186902', '0.01']
# ['186903', '-0.15']
# ['186904', '-0.11']
# ['186905', '-0.12']
# ['186906', '-0.09']
# ['186907', '-0.15']
# ['186908', '-0.19']
# ['186909', '-0.17']
# ['186910', '-0.24']
# ['186911', '-0.01']
# ['186912', '-0.08']
# ['187001', '-0.05']
# ['187002', '-0.16']
# ['187003', '-0.04']
# ['187004', '-0.10']
# ['187005', '-0.11']
# ['187006', '-0.14']
# ['187007', '-0.11']
# ['187008', '-0.16']
# ['187009', '-0.20']
# ['187010', '-0.31']
# ['187011', '-0.23']
# ['187012', '-0.37']
# ['187101', '-0.28']
# ['187102', '-0.31']
# ['187103', '-0.01']
# ['187104', '-0.03']
# ['187105', '-0.13']
# ['187106', '-0.12']
# ['187107', '-0.09']
# ['187108', '-0.16']
# ['187109', '-0.23']
# ['187110', '-0.25']
# ['187111', '-0.23']
# ['187112', '-0.24']
# ['187201', '-0.19']
# ['187202', '-0.19']
# ['187203', '-0.21']
# ['187204', '-0.20']
# ['187205', '-0.17']
# ['187206', '-0.17']
# ['187207', '-0.14']
# ['187208', '-0.10']
# ['187209', '-0.20']
# ['187210', '-0.14']
# ['187211', '-0.17']
# ['187212', '-0.29']
# ['187301', '-0.11']
# ['187302', '-0.18']
# ['187303', '-0.26']
# ['187304', '-0.43']
# ['187305', '-0.29']
# ['187306', '-0.14']
# ['187307', '-0.12']
# ['187308', '-0.09']
# ['187309', '-0.19']
# ['187310', '-0.19']
# ['187311', '-0.18']
# ['187312', '-0.13']
# ['187401', '-0.05']
# ['187402', '-0.17']
# ['187403', '-0.29']
# ['187404', '-0.28']
# ['187405', '-0.30']
# ['187406', '-0.26']
# ['187407', '-0.15']
# ['187408', '-0.13']
# ['187409', '-0.16']
# ['187410', '-0.20']
# ['187411', '-0.25']
# ['187412', '-0.26']
# ['187501', '-0.39']
# ['187502', '-0.20']
# ['187503', '-0.20']
# ['187504', '-0.22']
# ['187505', '-0.09']
# ['187506', '-0.07']
# ['187507', '-0.10']
# ['187508', '-0.08']
# ['187509', '-0.16']
# ['187510', '-0.14']
# ['187511', '-0.34']
# ['187512', '-0.30']
# ['187601', '-0.25']
# ['187602', '-0.23']
# ['187603', '-0.15']
# ['187604', '-0.27']
# ['187605', '-0.35']
# ['187606', '-0.18']
# ['187607', '-0.15']
# ['187608', '-0.15']
# ['187609', '-0.19']
# ['187610', '-0.15']
# ['187611', '-0.26']
# ['187612', '-0.22']
# ['187701', '-0.15']
# ['187702', '-0.01']
# ['187703', '0.04']
# ['187704', '-0.09']
# ['187705', '-0.04']
# ['187706', '0.07']
# ['187707', '0.13']
# ['187708', '0.11']
# ['187709', '0.14']
# ['187710', '0.12']
# ['187711', '0.20']
# ['187712', '0.11']
# ['187801', '0.11']
# ['187802', '0.24']
# ['187803', '0.26']
# ['187804', '0.07']
# ['187805', '0.04']
# ['187806', '0.11']
# ['187807', '0.05']
# ['187808', '0.04']
# ['187809', '0.02']
# ['187810', '-0.05']
# ['187811', '-0.08']
# ['187812', '-0.07']
# ['187901', '-0.06']
# ['187902', '-0.03']
# ['187903', '-0.03']
# ['187904', '-0.05']
# ['187905', '-0.04']
# ['187906', '-0.12']
# ['187907', '-0.07']
# ['187908', '-0.17']
# ['187909', '-0.13']
# ['187910', '-0.08']
# ['187911', '-0.21']
# ['187912', '-0.30']
# ['188001', '-0.16']
# ['188002', '-0.18']
# ['188003', '-0.11']
# ['188004', '-0.15']
# ['188005', '-0.07']
# ['188006', '-0.20']
# ['188007', '-0.22']
# ['188008', '-0.13']
# ['188009', '-0.17']
# ['188010', '-0.30']
# ['188011', '-0.18']
# ['188012', '-0.16']
# ['188101', '-0.16']
# ['188102', '-0.17']
# ['188103', '-0.08']
# ['188104', '-0.02']
# ['188105', '-0.01']
# ['188106', '-0.20']
# ['188107', '-0.09']
# ['188108', '-0.06']
# ['188109', '-0.18']
# ['188110', '-0.25']
# ['188111', '-0.26']
# ['188112', '-0.09']
# ['188201', '0.15']
# ['188202', '0.05']
# ['188203', '-0.02']
# ['188204', '-0.19']
# ['188205', '-0.20']
# ['188206', '-0.22']
# ['188207', '-0.18']
# ['188208', '-0.07']
# ['188209', '-0.11']
# ['188210', '-0.29']
# ['188211', '-0.22']
# ['188212', '-0.24']
# ['188301', '-0.33']
# ['188302', '-0.35']
# ['188303', '-0.17']
# ['188304', '-0.18']
# ['188305', '-0.16']
# ['188306', '-0.16']
# ['188307', '-0.12']
# ['188308', '-0.16']
# ['188309', '-0.28']
# ['188310', '-0.24']
# ['188311', '-0.28']
# ['188312', '-0.23']
# ['188401', '-0.17']
# ['188402', '-0.21']
# ['188403', '-0.31']
# ['188404', '-0.36']
# ['188405', '-0.32']
# ['188406', '-0.33']
# ['188407', '-0.37']
# ['188408', '-0.32']
# ['188409', '-0.31']
# ['188410', '-0.30']
# ['188411', '-0.41']
# ['188412', '-0.34']
# ['188501', '-0.58']
# ['188502', '-0.37']
# ['188503', '-0.27']
# ['188504', '-0.37']
# ['188505', '-0.41']
# ['188506', '-0.37']
# ['188507', '-0.38']
# ['188508', '-0.31']
# ['188509', '-0.27']
# ['188510', '-0.28']
# ['188511', '-0.24']
# ['188512', '-0.09']
# ['188601', '-0.30']
# ['188602', '-0.32']
# ['188603', '-0.28']
# ['188604', '-0.21']
# ['188605', '-0.22']
# ['188606', '-0.28']
# ['188607', '-0.22']
# ['188608', '-0.30']
# ['188609', '-0.28']
# ['188610', '-0.21']
# ['188611', '-0.25']
# ['188612', '-0.27']
# ['188701', '-0.54']
# ['188702', '-0.42']
# ['188703', '-0.27']
# ['188704', '-0.29']
# ['188705', '-0.27']
# ['188706', '-0.25']
# ['188707', '-0.29']
# ['188708', '-0.35']
# ['188709', '-0.19']
# ['188710', '-0.35']
# ['188711', '-0.27']
# ['188712', '-0.27']
# ['188801', '-0.30']
# ['188802', '-0.33']
# ['188803', '-0.34']
# ['188804', '-0.20']
# ['188805', '-0.16']
# ['188806', '-0.12']
# ['188807', '-0.13']
# ['188808', '-0.19']
# ['188809', '-0.15']
# ['188810', '-0.06']
# ['188811', '-0.08']
# ['188812', '-0.06']
# ['188901', '-0.05']
# ['188902', '0.10']
# ['188903', '0.05']
# ['188904', '0.04']
# ['188905', '0.01']
# ['188906', '-0.03']
# ['188907', '-0.07']
# ['188908', '-0.12']
# ['188909', '-0.19']
# ['188910', '-0.25']
# ['188911', '-0.29']
# ['188912', '-0.20']
# ['189001', '-0.36']
# ['189002', '-0.28']
# ['189003', '-0.24']
# ['189004', '-0.23']
# ['189005', '-0.27']
# ['189006', '-0.21']
# ['189007', '-0.25']
# ['189008', '-0.34']
# ['189009', '-0.28']
# ['189010', '-0.31']
# ['189011', '-0.44']
# ['189012', '-0.23']
# ['189101', '-0.29']
# ['189102', '-0.35']
# ['189103', '-0.22']
# ['189104', '-0.22']
# ['189105', '-0.11']
# ['189106', '-0.13']
# ['189107', '-0.13']
# ['189108', '-0.15']
# ['189109', '-0.11']
# ['189110', '-0.23']
# ['189111', '-0.32']
# ['189112', '-0.06']
# ['189201', '-0.22']
# ['189202', '-0.15']
# ['189203', '-0.27']
# ['189204', '-0.23']
# ['189205', '-0.17']
# ['189206', '-0.20']
# ['189207', '-0.31']
# ['189208', '-0.27']
# ['189209', '-0.17']
# ['189210', '-0.24']
# ['189211', '-0.38']
# ['189212', '-0.49']
# ['189301', '-0.68']
# ['189302', '-0.58']
# ['189303', '-0.29']
# ['189304', '-0.25']
# ['189305', '-0.32']
# ['189306', '-0.21']
# ['189307', '-0.21']
# ['189308', '-0.28']
# ['189309', '-0.29']
# ['189310', '-0.27']
# ['189311', '-0.25']
# ['189312', '-0.29']
# ['189401', '-0.36']
# ['189402', '-0.16']
# ['189403', '-0.16']
# ['189404', '-0.32']
# ['189405', '-0.21']
# ['189406', '-0.29']
# ['189407', '-0.20']
# ['189408', '-0.22']
# ['189409', '-0.25']
# ['189410', '-0.28']
# ['189411', '-0.26']
# ['189412', '-0.20']
# ['189501', '-0.35']
# ['189502', '-0.37']
# ['189503', '-0.32']
# ['189504', '-0.20']
# ['189505', '-0.18']
# ['189506', '-0.18']
# ['189507', '-0.15']
# ['189508', '-0.15']
# ['189509', '-0.10']
# ['189510', '-0.12']
# ['189511', '-0.16']
# ['189512', '-0.08']
# ['189601', '-0.17']
# ['189602', '-0.05']
# ['189603', '-0.16']
# ['189604', '-0.14']
# ['189605', '-0.07']
# ['189606', '-0.07']
# ['189607', '-0.02']
# ['189608', '-0.04']
# ['189609', '-0.02']
# ['189610', '0.03']
# ['189611', '-0.07']
# ['189612', '0.00']
# ['189701', '-0.07']
# ['189702', '-0.11']
# ['189703', '-0.14']
# ['189704', '0.07']
# ['189705', '0.09']
# ['189706', '-0.11']
# ['189707', '-0.06']
# ['189708', '-0.05']
# ['189709', '-0.04']
# ['189710', '-0.10']
# ['189711', '-0.19']
# ['189712', '-0.20']
# ['189801', '0.00']
# ['189802', '-0.22']
# ['189803', '-0.47']
# ['189804', '-0.26']
# ['189805', '-0.21']
# ['189806', '-0.15']
# ['189807', '-0.18']
# ['189808', '-0.21']
# ['189809', '-0.23']
# ['189810', '-0.37']
# ['189811', '-0.33']
# ['189812', '-0.16']
# ['189901', '-0.24']
# ['189902', '-0.31']
# ['189903', '-0.31']
# ['189904', '-0.23']
# ['189905', '-0.19']
# ['189906', '-0.23']
# ['189907', '-0.11']
# ['189908', '-0.03']
# ['189909', '-0.02']
# ['189910', '-0.08']
# ['189911', '0.00']
# ['189912', '-0.27']
# ['190001', '-0.31']
# ['190002', '-0.17']
# ['190003', '-0.03']
# ['190004', '-0.04']
# ['190005', '-0.06']
# ['190006', '-0.07']
# ['190007', '-0.11']
# ['190008', '-0.07']
# ['190009', '-0.05']
# ['190010', '0.04']
# ['190011', '-0.08']
# ['190012', '-0.06']
# ['190101', '-0.12']
# ['190102', '-0.08']
# ['190103', '0.03']
# ['190104', '0.00']
# ['190105', '-0.09']
# ['190106', '-0.08']
# ['190107', '-0.09']
# ['190108', '-0.15']
# ['190109', '-0.19']
# ['190110', '-0.28']
# ['190111', '-0.22']
# ['190112', '-0.38']
# ['190201', '-0.17']
# ['190202', '-0.05']
# ['190203', '-0.27']
# ['190204', '-0.28']
# ['190205', '-0.27']
# ['190206', '-0.26']
# ['190207', '-0.24']
# ['190208', '-0.23']
# ['190209', '-0.22']
# ['190210', '-0.28']
# ['190211', '-0.32']
# ['190212', '-0.27']
# ['190301', '-0.16']
# ['190302', '-0.03']
# ['190303', '-0.17']
# ['190304', '-0.31']
# ['190305', '-0.34']
# ['190306', '-0.31']
# ['190307', '-0.32']
# ['190308', '-0.40']
# ['190309', '-0.42']
# ['190310', '-0.48']
# ['190311', '-0.47']
# ['190312', '-0.46']
# ['190401', '-0.49']
# ['190402', '-0.53']
# ['190403', '-0.54']
# ['190404', '-0.47']
# ['190405', '-0.46']
# ['190406', '-0.40']
# ['190407', '-0.44']
# ['190408', '-0.42']
# ['190409', '-0.49']
# ['190410', '-0.35']
# ['190411', '-0.26']
# ['190412', '-0.34']
# ['190501', '-0.27']
# ['190502', '-0.45']
# ['190503', '-0.36']
# ['190504', '-0.42']
# ['190505', '-0.24']
# ['190506', '-0.20']
# ['190507', '-0.18']
# ['190508', '-0.22']
# ['190509', '-0.21']
# ['190510', '-0.23']
# ['190511', '-0.09']
# ['190512', '-0.09']
# ['190601', '-0.21']
# ['190602', '-0.21']
# ['190603', '-0.20']
# ['190604', '-0.09']
# ['190605', '-0.21']
# ['190606', '-0.15']
# ['190607', '-0.21']
# ['190608', '-0.21']
# ['190609', '-0.26']
# ['190610', '-0.21']
# ['190611', '-0.35']
# ['190612', '-0.19']
# ['190701', '-0.36']
# ['190702', '-0.40']
# ['190703', '-0.25']
# ['190704', '-0.30']
# ['190705', '-0.39']
# ['190706', '-0.31']
# ['190707', '-0.34']
# ['190708', '-0.30']
# ['190709', '-0.32']
# ['190710', '-0.26']
# ['190711', '-0.38']
# ['190712', '-0.42']
# ['190801', '-0.37']
# ['190802', '-0.31']
# ['190803', '-0.51']
# ['190804', '-0.41']
# ['190805', '-0.34']
# ['190806', '-0.31']
# ['190807', '-0.35']
# ['190808', '-0.42']
# ['190809', '-0.36']
# ['190810', '-0.44']
# ['190811', '-0.54']
# ['190812', '-0.44']
# ['190901', '-0.50']
# ['190902', '-0.38']
# ['190903', '-0.52']
# ['190904', '-0.59']
# ['190905', '-0.48']
# ['190906', '-0.46']
# ['190907', '-0.40']
# ['190908', '-0.33']
# ['190909', '-0.36']
# ['190910', '-0.39']
# ['190911', '-0.38']
# ['190912', '-0.42']
# ['191001', '-0.30']
# ['191002', '-0.35']
# ['191003', '-0.52']
# ['191004', '-0.37']
# ['191005', '-0.31']
# ['191006', '-0.32']
# ['191007', '-0.30']
# ['191008', '-0.36']
# ['191009', '-0.38']
# ['191010', '-0.44']
# ['191011', '-0.51']
# ['191012', '-0.61']
# ['191101', '-0.55']
# ['191102', '-0.55']
# ['191103', '-0.59']
# ['191104', '-0.51']
# ['191105', '-0.46']
# ['191106', '-0.45']
# ['191107', '-0.41']
# ['191108', '-0.44']
# ['191109', '-0.39']
# ['191110', '-0.32']
# ['191111', '-0.17']
# ['191112', '-0.13']
# ['191201', '-0.24']
# ['191202', '-0.18']
# ['191203', '-0.32']
# ['191204', '-0.20']
# ['191205', '-0.18']
# ['191206', '-0.18']
# ['191207', '-0.38']
# ['191208', '-0.43']
# ['191209', '-0.52']
# ['191210', '-0.54']
# ['191211', '-0.38']
# ['191212', '-0.44']
# ['191301', '-0.34']
# ['191302', '-0.41']
# ['191303', '-0.39']
# ['191304', '-0.35']
# ['191305', '-0.40']
# ['191306', '-0.40']
# ['191307', '-0.33']
# ['191308', '-0.31']
# ['191309', '-0.34']
# ['191310', '-0.33']
# ['191311', '-0.25']
# ['191312', '-0.07']
# ['191401', '0.05']
# ['191402', '-0.06']
# ['191403', '-0.18']
# ['191404', '-0.29']
# ['191405', '-0.20']
# ['191406', '-0.23']
# ['191407', '-0.24']
# ['191408', '-0.18']
# ['191409', '-0.18']
# ['191410', '-0.11']
# ['191411', '-0.12']
# ['191412', '0.00']
# ['191501', '-0.17']
# ['191502', '-0.01']
# ['191503', '-0.05']
# ['191504', '0.08']
# ['191505', '0.00']
# ['191506', '-0.11']
# ['191507', '-0.06']
# ['191508', '-0.11']
# ['191509', '-0.19']
# ['191510', '-0.21']
# ['191511', '-0.13']
# ['191512', '-0.24']
# ['191601', '-0.20']
# ['191602', '-0.16']
# ['191603', '-0.26']
# ['191604', '-0.24']
# ['191605', '-0.26']
# ['191606', '-0.36']
# ['191607', '-0.31']
# ['191608', '-0.27']
# ['191609', '-0.28']
# ['191610', '-0.30']
# ['191611', '-0.41']
# ['191612', '-0.71']
# ['191701', '-0.61']
# ['191702', '-0.64']
# ['191703', '-0.64']
# ['191704', '-0.52']
# ['191705', '-0.53']
# ['191706', '-0.41']
# ['191707', '-0.26']
# ['191708', '-0.22']
# ['191709', '-0.21']
# ['191710', '-0.38']
# ['191711', '-0.33']
# ['191712', '-0.48']
# ['191801', '-0.44']
# ['191802', '-0.39']
# ['191803', '-0.28']
# ['191804', '-0.41']
# ['191805', '-0.40']
# ['191806', '-0.34']
# ['191807', '-0.28']
# ['191808', '-0.29']
# ['191809', '-0.16']
# ['191810', '-0.10']
# ['191811', '-0.08']
# ['191812', '-0.26']
# ['191901', '-0.15']
# ['191902', '-0.19']
# ['191903', '-0.19']
# ['191904', '-0.09']
# ['191905', '-0.22']
# ['191906', '-0.30']
# ['191907', '-0.27']
# ['191908', '-0.32']
# ['191909', '-0.24']
# ['191910', '-0.20']
# ['191911', '-0.35']
# ['191912', '-0.38']
# ['192001', '-0.26']
# ['192002', '-0.29']
# ['192003', '-0.11']
# ['192004', '-0.23']
# ['192005', '-0.25']
# ['192006', '-0.28']
# ['192007', '-0.27']
# ['192008', '-0.23']
# ['192009', '-0.18']
# ['192010', '-0.26']
# ['192011', '-0.24']
# ['192012', '-0.42']
# ['192101', '-0.09']
# ['192102', '-0.19']
# ['192103', '-0.23']
# ['192104', '-0.26']
# ['192105', '-0.21']
# ['192106', '-0.23']
# ['192107', '-0.13']
# ['192108', '-0.19']
# ['192109', '-0.18']
# ['192110', '-0.08']
# ['192111', '-0.15']
# ['192112', '-0.15']
# ['192201', '-0.29']
# ['192202', '-0.40']
# ['192203', '-0.11']
# ['192204', '-0.20']
# ['192205', '-0.27']
# ['192206', '-0.24']
# ['192207', '-0.26']
# ['192208', '-0.27']
# ['192209', '-0.30']
# ['192210', '-0.29']
# ['192211', '-0.16']
# ['192212', '-0.21']
# ['192301', '-0.25']
# ['192302', '-0.39']
# ['192303', '-0.33']
# ['192304', '-0.35']
# ['192305', '-0.27']
# ['192306', '-0.21']
# ['192307', '-0.29']
# ['192308', '-0.32']
# ['192309', '-0.26']
# ['192310', '-0.19']
# ['192311', '-0.05']
# ['192312', '0.00']
# ['192401', '-0.18']
# ['192402', '-0.18']
# ['192403', '-0.07']
# ['192404', '-0.22']
# ['192405', '-0.11']
# ['192406', '-0.22']
# ['192407', '-0.21']
# ['192408', '-0.30']
# ['192409', '-0.29']
# ['192410', '-0.32']
# ['192411', '-0.21']
# ['192412', '-0.37']
# ['192501', '-0.36']
# ['192502', '-0.40']
# ['192503', '-0.26']
# ['192504', '-0.24']
# ['192505', '-0.24']
# ['192506', '-0.28']
# ['192507', '-0.24']
# ['192508', '-0.16']
# ['192509', '-0.13']
# ['192510', '-0.17']
# ['192511', '0.02']
# ['192512', '0.08']
# ['192601', '0.12']
# ['192602', '0.00']
# ['192603', '0.09']
# ['192604', '-0.11']
# ['192605', '-0.17']
# ['192606', '-0.16']
# ['192607', '-0.22']
# ['192608', '-0.12']
# ['192609', '-0.14']
# ['192610', '-0.08']
# ['192611', '-0.06']
# ['192612', '-0.21']
# ['192701', '-0.28']
# ['192702', '-0.20']
# ['192703', '-0.33']
# ['192704', '-0.26']
# ['192705', '-0.20']
# ['192706', '-0.19']
# ['192707', '-0.16']
# ['192708', '-0.14']
# ['192709', '-0.08']
# ['192710', '-0.02']
# ['192711', '-0.05']
# ['192712', '-0.25']
# ['192801', '-0.05']
# ['192802', '-0.11']
# ['192803', '-0.23']
# ['192804', '-0.24']
# ['192805', '-0.17']
# ['192806', '-0.28']
# ['192807', '-0.16']
# ['192808', '-0.19']
# ['192809', '-0.15']
# ['192810', '-0.18']
# ['192811', '-0.11']
# ['192812', '-0.14']
# ['192901', '-0.42']
# ['192902', '-0.49']
# ['192903', '-0.32']
# ['192904', '-0.36']
# ['192905', '-0.31']
# ['192906', '-0.34']
# ['192907', '-0.29']
# ['192908', '-0.24']
# ['192909', '-0.23']
# ['192910', '-0.14']
# ['192911', '-0.12']
# ['192912', '-0.45']
# ['193001', '-0.29']
# ['193002', '-0.26']
# ['193003', '-0.08']
# ['193004', '-0.19']
# ['193005', '-0.17']
# ['193006', '-0.12']
# ['193007', '-0.12']
# ['193008', '-0.10']
# ['193009', '-0.10']
# ['193010', '-0.04']
# ['193011', '0.14']
# ['193012', '-0.02']
# ['193101', '-0.07']
# ['193102', '-0.17']
# ['193103', '-0.07']
# ['193104', '-0.15']
# ['193105', '-0.13']
# ['193106', '-0.01']
# ['193107', '0.00']
# ['193108', '-0.01']
# ['193109', '0.00']
# ['193110', '0.02']
# ['193111', '-0.09']
# ['193112', '-0.06']
# ['193201', '0.10']
# ['193202', '-0.13']
# ['193203', '-0.14']
# ['193204', '-0.04']
# ['193205', '-0.14']
# ['193206', '-0.17']
# ['193207', '-0.15']
# ['193208', '-0.15']
# ['193209', '-0.10']
# ['193210', '-0.10']
# ['193211', '-0.23']
# ['193212', '-0.23']
# ['193301', '-0.26']
# ['193302', '-0.31']
# ['193303', '-0.26']
# ['193304', '-0.20']
# ['193305', '-0.24']
# ['193306', '-0.28']
# ['193307', '-0.21']
# ['193308', '-0.19']
# ['193309', '-0.26']
# ['193310', '-0.19']
# ['193311', '-0.27']
# ['193312', '-0.34']
# ['193401', '-0.25']
# ['193402', '-0.03']
# ['193403', '-0.30']
# ['193404', '-0.28']
# ['193405', '-0.07']
# ['193406', '-0.08']
# ['193407', '-0.09']
# ['193408', '-0.08']
# ['193409', '-0.11']
# ['193410', '-0.02']
# ['193411', '0.08']
# ['193412', '-0.01']
# ['193501', '-0.30']
# ['193502', '0.11']
# ['193503', '-0.13']
# ['193504', '-0.30']
# ['193505', '-0.23']
# ['193506', '-0.20']
# ['193507', '-0.15']
# ['193508', '-0.14']
# ['193509', '-0.13']
# ['193510', '-0.03']
# ['193511', '-0.22']
# ['193512', '-0.10']
# ['193601', '-0.30']
# ['193602', '-0.36']
# ['193603', '-0.20']
# ['193604', '-0.13']
# ['193605', '-0.08']
# ['193606', '-0.10']
# ['193607', '-0.05']
# ['193608', '-0.07']
# ['193609', '-0.08']
# ['193610', '-0.05']
# ['193611', '0.01']
# ['193612', '0.00']
# ['193701', '-0.09']
# ['193702', '0.01']
# ['193703', '-0.18']
# ['193704', '-0.11']
# ['193705', '-0.01']
# ['193706', '0.03']
# ['193707', '0.02']
# ['193708', '0.06']
# ['193709', '0.15']
# ['193710', '0.12']
# ['193711', '0.13']
# ['193712', '0.03']
# ['193801', '0.07']
# ['193802', '0.02']
# ['193803', '0.05']
# ['193804', '0.07']
# ['193805', '-0.03']
# ['193806', '-0.09']
# ['193807', '-0.06']
# ['193808', '-0.03']
# ['193809', '0.06']
# ['193810', '0.12']
# ['193811', '0.08']
# ['193812', '-0.07']
# ['193901', '-0.09']
# ['193902', '-0.10']
# ['193903', '-0.16']
# ['193904', '-0.03']
# ['193905', '-0.01']
# ['193906', '-0.01']
# ['193907', '-0.02']
# ['193908', '0.02']
# ['193909', '-0.01']
# ['193910', '-0.01']
# ['193911', '0.07']
# ['193912', '0.47']
# ['194001', '0.08']
# ['194002', '0.08']
# ['194003', '0.14']
# ['194004', '0.21']
# ['194005', '0.16']
# ['194006', '0.12']
# ['194007', '0.15']
# ['194008', '0.11']
# ['194009', '0.18']
# ['194010', '0.15']
# ['194011', '0.17']
# ['194012', '0.33']
# ['194101', '0.22']
# ['194102', '0.33']
# ['194103', '0.11']
# ['194104', '0.23']
# ['194105', '0.21']
# ['194106', '0.16']
# ['194107', '0.22']
# ['194108', '0.20']
# ['194109', '0.09']
# ['194110', '0.36']
# ['194111', '0.27']
# ['194112', '0.25']
# ['194201', '0.31']
# ['194202', '0.05']
# ['194203', '0.08']
# ['194204', '0.14']
# ['194205', '0.15']
# ['194206', '0.10']
# ['194207', '0.00']
# ['194208', '-0.01']
# ['194209', '0.00']
# ['194210', '0.04']
# ['194211', '0.09']
# ['194212', '0.12']
# ['194301', '-0.03']
# ['194302', '0.12']
# ['194303', '-0.02']
# ['194304', '0.13']
# ['194305', '0.13']
# ['194306', '-0.02']
# ['194307', '0.06']
# ['194308', '0.02']
# ['194309', '0.08']
# ['194310', '0.26']
# ['194311', '0.23']
# ['194312', '0.24']
# ['194401', '0.31']
# ['194402', '0.25']
# ['194403', '0.30']
# ['194404', '0.21']
# ['194405', '0.24']
# ['194406', '0.24']
# ['194407', '0.20']
# ['194408', '0.19']
# ['194409', '0.32']
# ['194410', '0.29']
# ['194411', '0.14']
# ['194412', '0.17']
# ['194501', '0.18']
# ['194502', '0.06']
# ['194503', '0.10']
# ['194504', '0.25']
# ['194505', '0.12']
# ['194506', '0.11']
# ['194507', '0.12']
# ['194508', '0.29']
# ['194509', '0.22']
# ['194510', '0.18']
# ['194511', '0.10']
# ['194512', '-0.03']
# ['194601', '0.17']
# ['194602', '0.01']
# ['194603', '0.02']
# ['194604', '0.07']
# ['194605', '-0.01']
# ['194606', '-0.17']
# ['194607', '-0.11']
# ['194608', '-0.12']
# ['194609', '-0.06']
# ['194610', '-0.03']
# ['194611', '-0.02']
# ['194612', '-0.21']
# ['194701', '-0.03']
# ['194702', '-0.03']
# ['194703', '0.05']
# ['194704', '0.06']
# ['194705', '0.03']
# ['194706', '0.04']
# ['194707', '-0.01']
# ['194708', '-0.09']
# ['194709', '-0.11']
# ['194710', '0.06']
# ['194711', '0.00']
# ['194712', '-0.05']
# ['194801', '0.02']
# ['194802', '-0.08']
# ['194803', '-0.21']
# ['194804', '-0.04']
# ['194805', '0.05']
# ['194806', '-0.02']
# ['194807', '-0.04']
# ['194808', '-0.05']
# ['194809', '-0.10']
# ['194810', '-0.04']
# ['194811', '-0.07']
# ['194812', '-0.19']
# ['194901', '0.06']
# ['194902', '-0.15']
# ['194903', '0.04']
# ['194904', '-0.05']
# ['194905', '-0.03']
# ['194906', '-0.16']
# ['194907', '-0.09']
# ['194908', '-0.05']
# ['194909', '-0.10']
# ['194910', '-0.04']
# ['194911', '-0.03']
# ['194912', '-0.10']
# ['195001', '-0.20']
# ['195002', '-0.26']
# ['195003', '-0.07']
# ['195004', '-0.15']
# ['195005', '-0.02']
# ['195006', '-0.02']
# ['195007', '-0.09']
# ['195008', '-0.09']
# ['195009', '-0.06']
# ['195010', '-0.14']
# ['195011', '-0.25']
# ['195012', '-0.12']
# ['195101', '-0.31']
# ['195102', '-0.37']
# ['195103', '-0.16']
# ['195104', '-0.10']
# ['195105', '0.04']
# ['195106', '0.04']
# ['195107', '0.10']
# ['195108', '0.11']
# ['195109', '0.17']
# ['195110', '0.13']
# ['195111', '0.03']
# ['195112', '0.21']
# ['195201', '0.14']
# ['195202', '0.11']
# ['195203', '-0.03']
# ['195204', '0.07']
# ['195205', '0.08']
# ['195206', '0.05']
# ['195207', '0.07']
# ['195208', '0.06']
# ['195209', '0.09']
# ['195210', '0.01']
# ['195211', '-0.08']
# ['195212', '0.05']
# ['195301', '0.07']
# ['195302', '0.15']
# ['195303', '0.15']
# ['195304', '0.26']
# ['195305', '0.20']
# ['195306', '0.21']
# ['195307', '0.09']
# ['195308', '0.10']
# ['195309', '0.07']
# ['195310', '0.13']
# ['195311', '0.04']
# ['195312', '0.07']
# ['195401', '-0.20']
# ['195402', '-0.06']
# ['195403', '-0.14']
# ['195404', '-0.08']
# ['195405', '-0.11']
# ['195406', '-0.06']
# ['195407', '-0.08']
# ['195408', '-0.05']
# ['195409', '-0.01']
# ['195410', '-0.01']
# ['195411', '0.09']
# ['195412', '-0.12']
# ['195501', '0.13']
# ['195502', '-0.17']
# ['195503', '-0.29']
# ['195504', '-0.20']
# ['195505', '-0.15']
# ['195506', '-0.08']
# ['195507', '-0.11']
# ['195508', '-0.02']
# ['195509', '-0.04']
# ['195510', '-0.09']
# ['195511', '-0.26']
# ['195512', '-0.27']
# ['195601', '-0.11']
# ['195602', '-0.17']
# ['195603', '-0.16']
# ['195604', '-0.25']
# ['195605', '-0.26']
# ['195606', '-0.16']
# ['195607', '-0.12']
# ['195608', '-0.19']
# ['195609', '-0.23']
# ['195610', '-0.22']
# ['195611', '-0.15']
# ['195612', '-0.02']
# ['195701', '-0.06']
# ['195702', '-0.09']
# ['195703', '-0.09']
# ['195704', '-0.05']
# ['195705', '0.06']
# ['195706', '0.15']
# ['195707', '0.01']
# ['195708', '0.26']
# ['195709', '0.17']
# ['195710', '0.09']
# ['195711', '0.08']
# ['195712', '0.17']
# ['195801', '0.35']
# ['195802', '0.26']
# ['195803', '0.12']
# ['195804', '0.06']
# ['195805', '0.10']
# ['195806', '-0.03']
# ['195807', '0.02']
# ['195808', '0.01']
# ['195809', '-0.03']
# ['195810', '0.04']
# ['195811', '0.03']
# ['195812', '0.08']
# ['195901', '0.07']
# ['195902', '0.10']
# ['195903', '0.19']
# ['195904', '0.17']
# ['195905', '0.04']
# ['195906', '0.11']
# ['195907', '0.08']
# ['195908', '0.04']
# ['195909', '0.10']
# ['195910', '-0.06']
# ['195911', '-0.03']
# ['195912', '0.02']
# ['196001', '0.05']
# ['196002', '0.11']
# ['196003', '-0.25']
# ['196004', '-0.09']
# ['196005', '-0.04']
# ['196006', '0.08']
# ['196007', '0.08']
# ['196008', '0.01']
# ['196009', '0.13']
# ['196010', '0.08']
# ['196011', '-0.11']
# ['196012', '0.26']
# ['196101', '0.14']
# ['196102', '0.18']
# ['196103', '0.10']
# ['196104', '0.21']
# ['196105', '0.04']
# ['196106', '0.10']
# ['196107', '0.05']
# ['196108', '0.05']
# ['196109', '0.08']
# ['196110', '-0.11']
# ['196111', '0.04']
# ['196112', '-0.09']
# ['196201', '0.08']
# ['196202', '0.11']
# ['196203', '0.16']
# ['196204', '-0.01']
# ['196205', '0.02']
# ['196206', '-0.06']
# ['196207', '0.10']
# ['196208', '0.07']
# ['196209', '-0.04']
# ['196210', '0.02']
# ['196211', '0.11']
# ['196212', '0.06']
# ['196301', '0.02']
# ['196302', '0.21']
# ['196303', '-0.13']
# ['196304', '0.01']
# ['196305', '-0.02']
# ['196306', '0.09']
# ['196307', '0.04']
# ['196308', '0.17']
# ['196309', '0.13']
# ['196310', '0.21']
# ['196311', '0.19']
# ['196312', '0.05']
# ['196401', '-0.08']
# ['196402', '-0.10']
# ['196403', '-0.15']
# ['196404', '-0.24']
# ['196405', '-0.15']
# ['196406', '-0.04']
# ['196407', '-0.01']
# ['196408', '-0.19']
# ['196409', '-0.15']
# ['196410', '-0.27']
# ['196411', '-0.20']
# ['196412', '-0.23']
# ['196501', '-0.08']
# ['196502', '-0.15']
# ['196503', '-0.11']
# ['196504', '-0.11']
# ['196505', '-0.19']
# ['196506', '-0.07']
# ['196507', '0.00']
# ['196508', '0.01']
# ['196509', '-0.07']
# ['196510', '0.01']
# ['196511', '0.03']
# ['196512', '-0.02']
# ['196601', '-0.14']
# ['196602', '-0.04']
# ['196603', '-0.02']
# ['196604', '-0.07']
# ['196605', '-0.10']
# ['196606', '0.11']
# ['196607', '0.09']
# ['196608', '-0.02']
# ['196609', '0.06']
# ['196610', '-0.14']
# ['196611', '0.01']
# ['196612', '0.01']
# ['196701', '-0.11']
# ['196702', '-0.15']
# ['196703', '0.05']
# ['196704', '0.00']
# ['196705', '0.21']
# ['196706', '0.02']
# ['196707', '-0.02']
# ['196708', '0.08']
# ['196709', '-0.04']
# ['196710', '0.12']
# ['196711', '-0.04']
# ['196712', '0.04']
# ['196801', '-0.18']
# ['196802', '-0.10']
# ['196803', '0.17']
# ['196804', '-0.04']
# ['196805', '-0.17']
# ['196806', '-0.13']
# ['196807', '-0.05']
# ['196808', '-0.03']
# ['196809', '-0.11']
# ['196810', '0.04']
# ['196811', '-0.05']
# ['196812', '-0.07']
# ['196901', '-0.08']
# ['196902', '-0.11']
# ['196903', '0.08']
# ['196904', '0.11']
# ['196905', '0.18']
# ['196906', '0.00']
# ['196907', '0.11']
# ['196908', '0.10']
# ['196909', '0.14']
# ['196910', '0.10']
# ['196911', '0.15']
# ['196912', '0.32']
# ['197001', '0.15']
# ['197002', '0.21']
# ['197003', '0.07']
# ['197004', '0.09']
# ['197005', '0.05']
# ['197006', '0.05']
# ['197007', '0.03']
# ['197008', '0.03']
# ['197009', '0.06']
# ['197010', '-0.03']
# ['197011', '0.04']
# ['197012', '-0.10']
# ['197101', '-0.02']
# ['197102', '-0.15']
# ['197103', '-0.09']
# ['197104', '-0.09']
# ['197105', '-0.03']
# ['197106', '-0.06']
# ['197107', '-0.01']
# ['197108', '-0.02']
# ['197109', '0.01']
# ['197110', '-0.07']
# ['197111', '-0.05']
# ['197112', '-0.05']
# ['197201', '-0.24']
# ['197202', '-0.16']
# ['197203', '0.06']
# ['197204', '0.05']
# ['197205', '0.01']
# ['197206', '0.08']
# ['197207', '0.06']
# ['197208', '0.09']
# ['197209', '0.03']
# ['197210', '0.12']
# ['197211', '0.06']
# ['197212', '0.14']
# ['197301', '0.35']
# ['197302', '0.38']
# ['197303', '0.35']
# ['197304', '0.28']
# ['197305', '0.24']
# ['197306', '0.25']
# ['197307', '0.15']
# ['197308', '0.13']
# ['197309', '0.11']
# ['197310', '0.06']
# ['197311', '0.02']
# ['197312', '0.05']
# ['197401', '-0.08']
# ['197402', '-0.24']
# ['197403', '-0.01']
# ['197404', '-0.06']
# ['197405', '-0.02']
# ['197406', '-0.06']
# ['197407', '0.04']
# ['197408', '0.05']
# ['197409', '-0.02']
# ['197410', '-0.06']
# ['197411', '-0.09']
# ['197412', '-0.06']
# ['197501', '0.06']
# ['197502', '0.08']
# ['197503', '0.11']
# ['197504', '0.11']
# ['197505', '0.08']
# ['197506', '0.06']
# ['197507', '0.04']
# ['197508', '-0.02']
# ['197509', '0.04']
# ['197510', '-0.12']
# ['197511', '-0.17']
# ['197512', '-0.10']
# ['197601', '-0.01']
# ['197602', '-0.08']
# ['197603', '-0.13']
# ['197604', '0.04']
# ['197605', '-0.11']
# ['197606', '-0.05']
# ['197607', '-0.03']
# ['197608', '0.00']
# ['197609', '0.03']
# ['197610', '-0.16']
# ['197611', '-0.03']
# ['197612', '0.12']
# ['197701', '0.20']
# ['197702', '0.22']
# ['197703', '0.25']
# ['197704', '0.28']
# ['197705', '0.28']
# ['197706', '0.26']
# ['197707', '0.18']
# ['197708', '0.16']
# ['197709', '0.20']
# ['197710', '0.12']
# ['197711', '0.23']
# ['197712', '0.11']
# ['197801', '0.15']
# ['197802', '0.15']
# ['197803', '0.23']
# ['197804', '0.14']
# ['197805', '0.10']
# ['197806', '0.05']
# ['197807', '0.06']
# ['197808', '0.00']
# ['197809', '0.10']
# ['197810', '0.07']
# ['197811', '0.20']
# ['197812', '0.12']
# ['197901', '0.14']
# ['197902', '-0.06']
# ['197903', '0.20']
# ['197904', '0.10']
# ['197905', '0.17']
# ['197906', '0.23']
# ['197907', '0.23']
# ['197908', '0.25']
# ['197909', '0.28']
# ['197910', '0.31']
# ['197911', '0.31']
# ['197912', '0.50']
# ['198001', '0.35']
# ['198002', '0.43']
# ['198003', '0.32']
# ['198004', '0.33']
# ['198005', '0.38']
# ['198006', '0.28']
# ['198007', '0.27']
# ['198008', '0.22']
# ['198009', '0.21']
# ['198010', '0.20']
# ['198011', '0.27']
# ['198012', '0.23']
# ['198101', '0.55']
# ['198102', '0.43']
# ['198103', '0.45']
# ['198104', '0.38']
# ['198105', '0.31']
# ['198106', '0.34']
# ['198107', '0.27']
# ['198108', '0.26']
# ['198109', '0.23']
# ['198110', '0.25']
# ['198111', '0.31']
# ['198112', '0.45']
# ['198201', '0.11']
# ['198202', '0.21']
# ['198203', '0.12']
# ['198204', '0.21']
# ['198205', '0.18']
# ['198206', '0.16']
# ['198207', '0.19']
# ['198208', '0.15']
# ['198209', '0.23']
# ['198210', '0.18']
# ['198211', '0.13']
# ['198212', '0.41']
# ['198301', '0.51']
# ['198302', '0.46']
# ['198303', '0.44']
# ['198304', '0.25']
# ['198305', '0.29']
# ['198306', '0.31']
# ['198307', '0.31']
# ['198308', '0.36']
# ['198309', '0.35']
# ['198310', '0.23']
# ['198311', '0.38']
# ['198312', '0.27']
# ['198401', '0.31']
# ['198402', '0.22']
# ['198403', '0.28']
# ['198404', '0.13']
# ['198405', '0.32']
# ['198406', '0.17']
# ['198407', '0.16']
# ['198408', '0.19']
# ['198409', '0.20']
# ['198410', '0.20']
# ['198411', '0.11']
# ['198412', '0.06']
# ['198501', '0.29']
# ['198502', '0.08']
# ['198503', '0.25']
# ['198504', '0.12']
# ['198505', '0.22']
# ['198506', '0.16']
# ['198507', '0.10']
# ['198508', '0.15']
# ['198509', '0.16']
# ['198510', '0.16']
# ['198511', '0.14']
# ['198512', '0.17']
# ['198601', '0.23']
# ['198602', '0.39']
# ['198603', '0.33']
# ['198604', '0.27']
# ['198605', '0.35']
# ['198606', '0.22']
# ['198607', '0.13']
# ['198608', '0.15']
# ['198609', '0.04']
# ['198610', '0.18']
# ['198611', '0.13']
# ['198612', '0.17']
# ['198701', '0.30']
# ['198702', '0.36']
# ['198703', '0.15']
# ['198704', '0.21']
# ['198705', '0.33']
# ['198706', '0.40']
# ['198707', '0.46']
# ['198708', '0.34']
# ['198709', '0.40']
# ['198710', '0.34']
# ['198711', '0.26']
# ['198712', '0.48']
# ['198801', '0.54']
# ['198802', '0.46']
# ['198803', '0.46']
# ['198804', '0.46']
# ['198805', '0.48']
# ['198806', '0.41']
# ['198807', '0.39']
# ['198808', '0.50']
# ['198809', '0.41']
# ['198810', '0.40']
# ['198811', '0.16']
# ['198812', '0.32']
# ['198901', '0.12']
# ['198902', '0.33']
# ['198903', '0.36']
# ['198904', '0.40']
# ['198905', '0.24']
# ['198906', '0.10']
# ['198907', '0.33']
# ['198908', '0.32']
# ['198909', '0.40']
# ['198910', '0.35']
# ['198911', '0.19']
# ['198912', '0.40']
# ['199001', '0.40']
# ['199002', '0.38']
# ['199003', '0.78']
# ['199004', '0.61']
# ['199005', '0.50']
# ['199006', '0.42']
# ['199007', '0.36']
# ['199008', '0.38']
# ['199009', '0.30']
# ['199010', '0.41']
# ['199011', '0.42']
# ['199012', '0.41']
# ['199101', '0.42']
# ['199102', '0.52']
# ['199103', '0.38']
# ['199104', '0.59']
# ['199105', '0.43']
# ['199106', '0.56']
# ['199107', '0.41']
# ['199108', '0.37']
# ['199109', '0.39']
# ['199110', '0.33']
# ['199111', '0.31']
# ['199112', '0.32']
# ['199201', '0.44']
# ['199202', '0.42']
# ['199203', '0.46']
# ['199204', '0.23']
# ['199205', '0.37']
# ['199206', '0.29']
# ['199207', '0.13']
# ['199208', '0.11']
# ['199209', '0.06']
# ['199210', '0.02']
# ['199211', '0.05']
# ['199212', '0.22']
# ['199301', '0.34']
# ['199302', '0.39']
# ['199303', '0.38']
# ['199304', '0.36']
# ['199305', '0.31']
# ['199306', '0.32']
# ['199307', '0.31']
# ['199308', '0.11']
# ['199309', '0.21']
# ['199310', '0.22']
# ['199311', '0.10']
# ['199312', '0.18']
# ['199401', '0.22']
# ['199402', '0.06']
# ['199403', '0.30']
# ['199404', '0.41']
# ['199405', '0.32']
# ['199406', '0.43']
# ['199407', '0.32']
# ['199408', '0.26']
# ['199409', '0.27']
# ['199410', '0.45']
# ['199411', '0.42']
# ['199412', '0.40']
# ['199501', '0.55']
# ['199502', '0.77']
# ['199503', '0.49']
# ['199504', '0.51']
# ['199505', '0.33']
# ['199506', '0.50']
# ['199507', '0.45']
# ['199508', '0.50']
# ['199509', '0.44']
# ['199510', '0.44']
# ['199511', '0.48']
# ['199512', '0.32']
# ['199601', '0.28']
# ['199602', '0.49']
# ['199603', '0.37']
# ['199604', '0.37']
# ['199605', '0.34']
# ['199606', '0.38']
# ['199607', '0.35']
# ['199608', '0.44']
# ['199609', '0.28']
# ['199610', '0.17']
# ['199611', '0.44']
# ['199612', '0.38']
# ['199701', '0.30']
# ['199702', '0.39']
# ['199703', '0.52']
# ['199704', '0.41']
# ['199705', '0.42']
# ['199706', '0.57']
# ['199707', '0.42']
# ['199708', '0.47']
# ['199709', '0.59']
# ['199710', '0.68']
# ['199711', '0.65']
# ['199712', '0.59']
# ['199801', '0.58']
# ['199802', '0.83']
# ['199803', '0.68']
# ['199804', '0.70']
# ['199805', '0.69']
# ['199806', '0.76']
# ['199807', '0.70']
# ['199808', '0.68']
# ['199809', '0.48']
# ['199810', '0.44']
# ['199811', '0.45']
# ['199812', '0.59']
# ['199901', '0.49']
# ['199902', '0.63']
# ['199903', '0.39']
# ['199904', '0.37']
# ['199905', '0.34']
# ['199906', '0.38']
# ['199907', '0.41']
# ['199908', '0.33']
# ['199909', '0.46']
# ['199910', '0.37']
# ['199911', '0.38']
# ['199912', '0.47']
# ['200001', '0.34']
# ['200002', '0.57']
# ['200003', '0.59']
# ['200004', '0.61']
# ['200005', '0.39']
# ['200006', '0.37']
# ['200007', '0.41']
# ['200008', '0.46']
# ['200009', '0.43']
# ['200010', '0.33']
# ['200011', '0.33']
# ['200012', '0.31']
# ['200101', '0.44']
# ['200102', '0.46']
# ['200103', '0.57']
# ['200104', '0.56']
# ['200105', '0.58']
# ['200106', '0.55']
# ['200107', '0.62']
# ['200108', '0.48']
# ['200109', '0.58']
# ['200110', '0.47']
# ['200111', '0.71']
# ['200112', '0.63']
# ['200201', '0.68']
# ['200202', '0.70']
# ['200203', '0.86']
# ['200204', '0.56']
# ['200205', '0.66']
# ['200206', '0.54']
# ['200207', '0.59']
# ['200208', '0.53']
# ['200209', '0.66']
# ['200210', '0.56']
# ['200211', '0.62']
# ['200212', '0.50']
# ['200301', '0.71']
# ['200302', '0.57']
# ['200303', '0.61']
# ['200304', '0.61']
# ['200305', '0.64']
# ['200306', '0.52']
# ['200307', '0.60']
# ['200308', '0.60']
# ['200309', '0.66']
# ['200310', '0.77']
# ['200311', '0.56']
# ['200312', '0.75']
# ['200401', '0.58']
# ['200402', '0.67']
# ['200403', '0.66']
# ['200404', '0.66']
# ['200405', '0.43']
# ['200406', '0.48']
# ['200407', '0.33']
# ['200408', '0.44']
# ['200409', '0.52']
# ['200410', '0.61']
# ['200411', '0.72']
# ['200412', '0.49']
# ['200501', '0.75']
# ['200502', '0.63']
# ['200503', '0.77']
# ['200504', '0.71']
# ['200505', '0.71']
# ['200506', '0.67']
# ['200507', '0.66']
# ['200508', '0.59']
# ['200509', '0.73']
# ['200510', '0.75']
# ['200511', '0.79']
# ['200512', '0.74']
# ['200601', '0.63']
# ['200602', '0.81']
# ['200603', '0.67']
# ['200604', '0.53']
# ['200605', '0.52']
# ['200606', '0.66']
# ['200607', '0.55']
# ['200608', '0.73']
# ['200609', '0.69']
# ['200610', '0.68']
# ['200611', '0.72']
# ['200612', '0.78']
# ['200701', '0.94']
# ['200702', '0.73']
# ['200703', '0.69']
# ['200704', '0.81']
# ['200705', '0.66']
# ['200706', '0.58']
# ['200707', '0.59']
# ['200708', '0.58']
# ['200709', '0.61']
# ['200710', '0.61']
# ['200711', '0.58']
# ['200712', '0.52']
# ['200801', '0.29']
# ['200802', '0.35']
# ['200803', '0.74']
# ['200804', '0.53']
# ['200805', '0.52']
# ['200806', '0.51']
# ['200807', '0.57']
# ['200808', '0.48']
# ['200809', '0.63']
# ['200810', '0.70']
# ['200811', '0.71']
# ['200812', '0.57']
# ['200901', '0.67']
# ['200902', '0.52']
# ['200903', '0.54']
# ['200904', '0.59']
# ['200905', '0.62']
# ['200906', '0.64']
# ['200907', '0.72']
# ['200908', '0.71']
# ['200909', '0.74']
# ['200910', '0.70']
# ['200911', '0.81']
# ['200912', '0.70']
# ['201001', '0.75']
# ['201002', '0.83']
# ['201003', '0.90']
# ['201004', '0.89']
# ['201005', '0.79']
# ['201006', '0.71']
# ['201007', '0.67']
# ['201008', '0.67']
# ['201009', '0.62']
# ['201010', '0.68']
# ['201011', '0.80']
# ['201012', '0.52']
# ['201101', '0.56']
# ['201102', '0.51']
# ['201103', '0.68']
# ['201104', '0.66']
# ['201105', '0.56']
# ['201106', '0.63']
# ['201107', '0.73']
# ['201108', '0.70']
# ['201109', '0.61']
# ['201110', '0.71']
# ['201111', '0.60']
# ['201112', '0.61']
# ['201201', '0.48']
# ['201202', '0.54']
# ['201203', '0.55']
# ['201204', '0.75']
# ['201205', '0.75']
# ['201206', '0.67']
# ['201207', '0.64']
# ['201208', '0.65']
# ['201209', '0.76']
# ['201210', '0.79']
# ['201211', '0.80']
# ['201212', '0.56']
# ['201301', '0.70']
# ['201302', '0.62']
# ['201303', '0.68']
# ['201304', '0.58']
# ['201305', '0.67']
# ['201306', '0.68']
# ['201307', '0.61']
# ['201308', '0.70']
# ['201309', '0.77']
# ['201310', '0.68']
# ['201311', '0.81']
# ['201312', '0.72']
# ['201401', '0.75']
# ['201402', '0.57']
# ['201403', '0.82']
# ['201404', '0.86']
# ['201405', '0.87']
# ['201406', '0.73']
# ['201407', '0.62']
# ['201408', '0.83']
# ['201409', '0.87']
# ['201410', '0.82']
# ['201411', '0.69']
# ['201412', '0.79']
# ['201501', '0.82']
# ['201502', '0.89']
# ['201503', '0.97']
# ['201504', '0.81']
# ['201505', '0.83']
# ['201506', '0.88']
# ['201507', '0.77']
# ['201508', '0.83']
# ['201509', '0.91']
# ['201510', '1.11']
# ['201511', '1.06']
# ['201512', '1.14']
# ['201601', '1.22']
# ['201602', '1.34']
# ['201603', '1.35']
# ['201604', '1.15']
# ['201605', '1.00']
# ['201606', '0.84']
# ['201607', '0.86']
# ['201608', '0.96']
# ['201609', '0.92']
# ['201610', '0.89']
# ['201611', '0.94']
# ['201612', '0.90']
# ['201701', '1.05']
# ['201702', '1.11']
# ['201703', '1.17']
# ['201704', '0.98']
# ['201705', '0.91']
# ['201706', '0.77']
# ['201707', '0.83']
# ['201708', '0.89']
# ['201709', '0.84']
# ['201710', '0.92']
# ['201711', '0.92']
# ['201712', '0.99']
# ['201801', '0.83']
# ['201802', '0.89']
# ['201803', '0.93']
# ['201804', '0.89']
# ['201805', '0.82']
# ['201806', '0.76']
# ['201807', '0.80']
# ['201808', '0.76']
# ['201809', '0.82']
# ['201810', '1.05']
# ['201811', '0.84']
# ['201812', '0.93']
# ['201901', '0.91']
# ['201902', '0.92']
# ['201903', '1.16']
# ['201904', '1.03']
# ['201905', '0.90']
# ['201906', '0.91']
# ['201907', '0.91']
# ['201908', '0.91']
# ['201909', '0.96']
# ['201910', '1.01']
# ['201911', '0.99']
# ['201912', '1.09']
# ['202001', '1.13']
# ['202002', '1.20']
# ['202003', '1.16']
# ['202004', '1.14']
# ['202005', '0.99']
# ['202006', '0.93']
# ['202007', '0.91']
# ['202008', '0.90']
# ['202009', '0.98']
# ['202010', '0.90']
# ['202011', '1.05']
# ['202012', '0.84']
# ['202101', '0.83']
# ['202102', '0.66']
# ['202103', '0.88']
# ['202104', '0.80']
# ['202105', '0.81']
# ['202106', '0.85']
# ['202107', '0.92']
# ['202108', '0.84']
# ['202109', '0.91']
# ['202110', '0.99']
# ['202111', '0.95']
# ['202112', '0.87']
# ['202201', '0.93']
# ['202202', '0.91']
# ['202203', '1.11']
# ['202204', '0.90']
# ['202205', '0.86']
# ['202206', '0.89']
# ['202207', '0.89']
# ['202208', '0.93']
# ['202209', '0.90']
# ['202210', '0.97']
# ['202211', '0.75']
# ['202212', '0.84']
# ['202301', '0.87']
# ['202302', '1.01']
# ['202303', '1.23']
# ['202304', '0.98']
# ['202305', '0.96']
# ['202306', '1.07']
# ['202307', '1.12']

# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = "Global_Land_OceanTemp_Anom.csv"

try:
    # Read the CSV file and create a DataFrame
    df = pd.read_csv(csv_file_path, skiprows=4)  # Skip the first 4 rows

    # Display the DataFrame
    print(df)
except FileNotFoundError:
    print(f"File '{csv_file_path}' not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#         Year  Anomaly
# 0     185001    -0.39
# 1     185002    -0.15
# 2     185003    -0.26
# 3     185004    -0.22
# 4     185005    -0.21
# ...      ...      ...
# 2078  202303     1.23
# 2079  202304     0.98
# 2080  202305     0.96
# 2081  202306     1.07
# 2082  202307     1.12
#
# [2083 rows x 2 columns]
