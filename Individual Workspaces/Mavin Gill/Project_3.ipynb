# %%
#API Call of Ocean Warming Data
import requests

# New API URL
url = "https://global-warming.org/api/ocean-warming-api"

try:
    # Make the API request
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()  # Parse the JSON response

        # Extract the result dictionary from the data
        result = data['result']

        # Convert string values to floats
        ocean_warming_data = {year: float(value) for year, value in result.items()}

        print("Ocean warming data:")
        for year, value in ocean_warming_data.items():
            print(f"Year: {year}, Ocean Warming: {value}°C")
    else:
        print(f"API request failed with status code: {response.status_code}")
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")

# %%
# API URL
url = "https://global-warming.org/api/ocean-warming-api"

try:
    # Make the API request
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()  # Parse the JSON response

        # Extract years from the 'result' dictionary
        years = [year for year in data['result'].keys()]

        # Count the number of entries (years)
        num_entries = len(years)

        print(f"Number of entries (years): {num_entries}")
    else:
        print(f"API request failed with status code: {response.status_code}")
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")

# %%
import csv

# New API URL
url = "https://global-warming.org/api/ocean-warming-api"

try:
    # Make the API request
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()  # Parse the JSON response

        # Extract the result dictionary from the data
        result = data['result']

        # Convert string values to floats
        ocean_warming_data = {year: float(value) for year, value in result.items()}

        # Save data to a CSV file
        with open("ocean_warming_data.csv", mode="w", newline="") as csv_file:
            csv_writer = csv.writer(csv_file)
            csv_writer.writerow(["Year", "Ocean Warming (°C)"])  # Write header
            for year, value in ocean_warming_data.items():
                csv_writer.writerow([year, value])

        print("Ocean warming data saved to ocean_warming_data.csv")
    else:
        print(f"API request failed with status code: {response.status_code}")
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")

# %%
# Specify the path to your CSV file
csv_file_path = "ocean_warming_data.csv"

try:
    # Read the CSV file and create a DataFrame
    df = pd.read_csv(csv_file_path)  # Skip the first 4 rows

    # Display the DataFrame
    print(df)
except FileNotFoundError:
    print(f"File '{csv_file_path}' not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# Read the tab-separated CSV file
oceanwarming_df = pd.read_csv("ocean_warming_data.csv")

# Display the DataFrame
oceanwarming_df

# %%
import csv

# Specify the path to your CSV file
csv_file_path = "Global_Land_OceanTemp_Anom.csv"

try:
    # Open and read the CSV file
    with open(csv_file_path, "r") as csv_file:
        csv_reader = csv.reader(csv_file)  # Create a CSV reader object
        
        # Skip the first 5 rows
        for _ in range(5):
            next(csv_reader)

        # Loop through each row starting from the 6th row
        for row in csv_reader:
            # Process the row as needed
            print(row)
except FileNotFoundError:
    print(f"File '{csv_file_path}' not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = "Global_Land_OceanTemp_Anom.csv"

try:
    # Read the CSV file and create a DataFrame
    df = pd.read_csv(csv_file_path, skiprows=4)  # Skip the first 4 rows

    # Display the DataFrame
    print(df)
except FileNotFoundError:
    print(f"File '{csv_file_path}' not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# Specify the path to your CSV file
csv_file_path = "Global_Land_Temp_Anom.csv"

try:
    # Open and read the CSV file
    with open(csv_file_path, "r") as csv_file:
        csv_reader = csv.reader(csv_file)  # Create a CSV reader object
        
        # Skip the first 5 rows
        for _ in range(5):
            next(csv_reader)

        # Loop through each row starting from the 6th row
        for row in csv_reader:
            # Process the row as needed
            print(row)
except FileNotFoundError:
    print(f"File '{csv_file_path}' not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = "Global_Land_Temp_Anom.csv"

try:
    # Read the CSV file and create a DataFrame
    df = pd.read_csv(csv_file_path, skiprows=4)  # Skip the first 4 rows

    # Display the DataFrame
    print(df)
except FileNotFoundError:
    print(f"File '{csv_file_path}' not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# Specify the path to your CSV file
csv_file_path = "Global_Ocean_Temp_Anom.csv"

try:
    # Open and read the CSV file
    with open(csv_file_path, "r") as csv_file:
        csv_reader = csv.reader(csv_file)  # Create a CSV reader object
        
        # Skip the first 5 rows
        for _ in range(5):
            next(csv_reader)

        # Loop through each row starting from the 6th row
        for row in csv_reader:
            # Process the row as needed
            print(row)
except FileNotFoundError:
    print(f"File '{csv_file_path}' not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# Specify the path to your CSV file
csv_file_path = "Global_Ocean_Temp_Anom.csv"

try:
    # Read the CSV file and create a DataFrame
    df = pd.read_csv(csv_file_path, skiprows = 4)  # Skip the first 4 rows

    # Display the DataFrame
    print(df)
except FileNotFoundError:
    print(f"File '{csv_file_path}' not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
import pandas as pd

# Read the tab-separated CSV file
landocean_df = pd.read_csv("Global_Land_OceanTemp_Anom.csv",skiprows=4, delimiter=',')

# Display the DataFrame
landocean_df

# %%
# Read the tab-separated CSV file
landocean_df = pd.read_csv("Global_Land_Temp_Anom.csv",skiprows=4, delimiter=',')

# Display the DataFrame
landocean_df

# %%
# Read the tab-separated CSV file
landocean_df = pd.read_csv("Global_Ocean_Temp_Anom.csv",skiprows=4, delimiter=',')

# Display the DataFrame
landocean_df

# %%
from datetime import datetime
# Replace 1850 with the valid year you have
year = 1850
try:
    date_object = datetime(year, 1, 1)
    print("Date:", date_object.strftime("%Y-%m-%d"))
except ValueError:
    print("Invalid year")

# %%
from datetime import datetime
# Replace 1850 with the valid year you have
year = 1920
try:
    date_object = datetime(year, 1, 1)
    print("Date:", date_object.strftime("%Y-%m-%d"))
except ValueError:
    print("Invalid year")
