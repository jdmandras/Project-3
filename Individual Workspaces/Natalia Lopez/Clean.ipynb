# %%
# Dependencies
import requests
import json
import pandas as pd
import csv
import os

# %%
# Open and Read CSV File
aq_data_csv_file_path = '../../resources/aq_data.csv'

aq_data_frame = pd.read_csv(aq_data_csv_file_path)
aq_data_frame
# Out:
#          id  city                              name country
# 0     62480   NaN                           Kalmia       US  \
# 1     62492   NaN            Sutter Creek, Ridge Rd      US
# 2     62932   NaN                       MASUK-ANGIN      US
# 3     63284   NaN                      Troon Avenue      US
# 4     63497   NaN            The Syndicate Homebase      US
# ..      ...   ...                               ...     ...
# 95   748501   NaN    Venue Apts nw side upper floor      US
# 96   815770   NaN                     UEA_EducAIR_7      BR
# 97   921732   NaN               CleanAIRE NC Newell      NO
# 98  1060885   NaN                            LAWD 1      NO
# 99  1066313   NaN  RSD - Educational Service Center      NO
#
#                                            parameters
# 0   [{'id': 2, 'unit': 'µg/m³', 'count': 57144, 'a...
# 1   [{'id': 128, 'unit': 'f', 'count': 42872, 'ave...
# 2   [{'id': 125, 'unit': 'particles/cm³', 'count':...
# 3   [{'id': 129, 'unit': 'particles/cm³', 'count':...
# 4   [{'id': 129, 'unit': 'particles/cm³', 'count':...
# ..                                                ...
# 95  [{'id': 128, 'unit': 'f', 'count': 43122, 'ave...
# 96  [{'id': 132, 'unit': 'mb', 'count': 18331, 'av...
# 97  [{'id': 2, 'unit': 'µg/m³', 'count': 57526, 'a...
# 98  [{'id': 19, 'unit': 'µg/m³', 'count': 41229, '...
# 99  [{'id': 129, 'unit': 'particles/cm³', 'count':...
#
# [100 rows x 5 columns]

# %%
split_values = aq_data_frame['parameters'].str.split(',', expand=True)
split_values
# Out:
#             0                         1                2
# 0     [{'id': 2           'unit': 'µg/m³'   'count': 57144  \
# 1   [{'id': 128               'unit': 'f'   'count': 42872
# 2   [{'id': 125   'unit': 'particles/cm³'   'count': 43338
# 3   [{'id': 129   'unit': 'particles/cm³'   'count': 43715
# 4   [{'id': 129   'unit': 'particles/cm³'   'count': 42711
# ..          ...                       ...              ...
# 95  [{'id': 128               'unit': 'f'   'count': 43122
# 96  [{'id': 132              'unit': 'mb'   'count': 18331
# 97    [{'id': 2           'unit': 'µg/m³'   'count': 57526
# 98   [{'id': 19           'unit': 'µg/m³'   'count': 41229
# 99  [{'id': 129   'unit': 'particles/cm³'   'count': 23413
#
#                                   3                     4
# 0        'average': 7.873342477184909      'lastValue': 4.7  \
# 1         'average': 76.9599741588224     'lastValue': 82.0
# 2        'average': 6.884113613718417     'lastValue': 11.6
# 3     'average': 0.007072006900571081     'lastValue': 0.01
# 4    'average': 0.0005187436091889194     'lastValue': 0.04
# ..                                ...                   ...
# 95       'average': 79.62418520534045     'lastValue': 90.0
# 96      'average': 1004.1351134172015   'lastValue': 999.69
# 97      'average': 18.485256691490022     'lastValue': 17.8
# 98      'average': 18.801247617287366     'lastValue': 20.2
# 99    'average': 0.012349540412660178     'lastValue': 0.02
#
#                             5                                      6
# 0           'parameter': 'pm25'            'displayName': 'pm25 µg/m³'  \
# 1    'parameter': 'temperature'         'displayName': 'temperature f'
# 2          'parameter': 'um003'   'displayName': 'um003 particles/cm³'
# 3          'parameter': 'um050'   'displayName': 'um050 particles/cm³'
# 4          'parameter': 'um050'   'displayName': 'um050 particles/cm³'
# ..                          ...                                    ...
# 95   'parameter': 'temperature'         'displayName': 'temperature f'
# 96      'parameter': 'pressure'           'displayName': 'pressure mb'
# 97          'parameter': 'pm25'            'displayName': 'pm25 µg/m³'
# 98           'parameter': 'pm1'             'displayName': 'pm1 µg/m³'
# 99         'parameter': 'um050'   'displayName': 'um050 particles/cm³'
#
#                                             7                    8
# 0    'lastUpdated': '2023-08-22T01:24:22+00:00'     'parameterId': 2  \
# 1    'lastUpdated': '2023-08-22T01:24:22+00:00'   'parameterId': 128
# 2    'lastUpdated': '2023-08-22T01:24:22+00:00'   'parameterId': 125
# 3    'lastUpdated': '2023-08-22T01:24:22+00:00'   'parameterId': 129
# 4    'lastUpdated': '2023-08-22T01:24:22+00:00'   'parameterId': 129
# ..                                          ...                  ...
# 95   'lastUpdated': '2023-08-22T01:24:22+00:00'   'parameterId': 128
# 96   'lastUpdated': '2023-08-22T01:24:22+00:00'   'parameterId': 132
# 97   'lastUpdated': '2023-08-22T01:24:22+00:00'     'parameterId': 2
# 98   'lastUpdated': '2023-08-22T01:24:22+00:00'    'parameterId': 19
# 99   'lastUpdated': '2023-08-22T01:24:22+00:00'   'parameterId': 129
#
#                                              9    ...
# 0    'firstUpdated': '2023-05-08T00:12:18+00:00'  ...  \
# 1    'firstUpdated': '2023-05-23T18:00:26+00:00'  ...
# 2    'firstUpdated': '2023-05-23T17:58:13+00:00'  ...
# 3    'firstUpdated': '2023-05-23T18:00:41+00:00'  ...
# 4    'firstUpdated': '2023-05-23T17:29:30+00:00'  ...
# ..                                           ...  ...
# 95   'firstUpdated': '2023-05-23T18:00:19+00:00'  ...
# 96   'firstUpdated': '2023-05-31T15:45:13+00:00'  ...
# 97   'firstUpdated': '2023-05-08T00:06:13+00:00'  ...
# 98   'firstUpdated': '2023-06-02T13:29:30+00:00'  ...
# 99   'firstUpdated': '2023-06-07T18:33:54+00:00'  ...
#
#                          144              145                            146
# 0                       None             None                           None  \
# 1                       None             None                           None
# 2                       None             None                           None
# 3                       None             None                           None
# 4                       None             None                           None
# ..                       ...              ...                            ...
# 95                      None             None                           None
# 96                      None             None                           None
# 97   'unit': 'particles/cm³'   'count': 45045   'average': 32.05801472671032
# 98                      None             None                           None
# 99                      None             None                           None
#
#                     147                    148
# 0                  None                   None  \
# 1                  None                   None
# 2                  None                   None
# 3                  None                   None
# 4                  None                   None
# ..                  ...                    ...
# 95                 None                   None
# 96                 None                   None
# 97   'lastValue': 23.77   'parameter': 'um003'
# 98                 None                   None
# 99                 None                   None
#
#                                       149
# 0                                    None  \
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
# ..                                    ...
# 95                                   None
# 96                                   None
# 97   'displayName': 'um003 particles/cm³'
# 98                                   None
# 99                                   None
#
#                                             150                  151
# 0                                          None                 None  \
# 1                                          None                 None
# 2                                          None                 None
# 3                                          None                 None
# 4                                          None                 None
# ..                                          ...                  ...
# 95                                         None                 None
# 96                                         None                 None
# 97   'lastUpdated': '2023-08-22T01:24:22+00:00'   'parameterId': 125
# 98                                         None                 None
# 99                                         None                 None
#
#                                              152                       153
# 0                                           None                      None
# 1                                           None                      None
# 2                                           None                      None
# 3                                           None                      None
# 4                                           None                      None
# ..                                           ...                       ...
# 95                                          None                      None
# 96                                          None                      None
# 97   'firstUpdated': '2023-05-23T18:00:22+00:00'   'manufacturers': None}]
# 98                                          None                      None
# 99                                          None                      None
#
# [100 rows x 154 columns]
