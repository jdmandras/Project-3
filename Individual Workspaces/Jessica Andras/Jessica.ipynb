# %%
import pandas as pd

# %%
#Global Air Pollution

#read csv
global_ap_df = pd.read_csv("Resources/global air pollution dataset.csv")
global_ap_df
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
#Global Land/Ocean Temp Anomalies

#read csv
landocean_df = pd.read_csv("Resources/Global_Land_OceanTemp_Anom.csv")
landocean_df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[26], line 4
#       1 #Global Land/Ocean Temp Anomalies
#       2
#       3 #read csv
# ----> 4 landocean_df = pd.read_csv("Resources/Global_Land_OceanTemp_Anom.csv")
#       5 landocean_df
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
#World Cities

#read csv
worldcities_df = pd.read_csv("Resources/worldcities.csv")
worldcities_df
# Out:
#               city   city_ascii      lat       lng    country iso2 iso3  \
# 0            Tokyo        Tokyo  35.6897  139.6922      Japan   JP  JPN
# 1          Jakarta      Jakarta  -6.1750  106.8275  Indonesia   ID  IDN
# 2            Delhi        Delhi  28.6100   77.2300      India   IN  IND
# 3        Guangzhou    Guangzhou  23.1300  113.2600      China   CN  CHN
# 4           Mumbai       Mumbai  19.0761   72.8775      India   IN  IND
# ...            ...          ...      ...       ...        ...  ...  ...
# 44686        Numto        Numto  63.6667   71.3333     Russia   RU  RUS
# 44687         Nord         Nord  81.7166  -17.8000  Greenland   GL  GRL
# 44688  Timmiarmiut  Timmiarmiut  62.5333  -42.2167  Greenland   GL  GRL
# 44689   San Rafael   San Rafael -16.7795  -60.6799    Bolivia   BO  BOL
# 44690      Nordvik      Nordvik  74.0165  111.5100     Russia   RU  RUS
#
#                                      admin_name  capital  population  \
# ...
